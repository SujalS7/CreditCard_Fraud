# %% [markdown]
# <a href="https://colab.research.google.com/github/SujalS7/CreditCard_Fraud/blob/main/CreditcardFraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# installing kaggle library

# %%
! pip install Kaggle

# %% [markdown]
# configure the path of json file

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# ...
#  94% 62.0M/66.0M [00:00<00:00, 105MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 102MB/s]

# %% [markdown]
# Extract compressed dataset

# %%
from zipfile import ZipFile
dataset = '/content/creditcardfraud.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data = data.drop(['Time'],axis =1 )

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# convert "amount" values to standard form

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
data.duplicated().sum()
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()
data.shape
# Out:
# (275663, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %% [markdown]
# visualization

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
data['Class'].value_counts().plot(kind='bar', color=['blue', 'red'])
plt.show()

# %%
X = data.drop('Class', axis = 1)
Y = data['Class']

# %% [markdown]
# Random test ensures that every time same split occurs

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"\n=========={name}===========")
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(Y_test, Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test, Y_pred)}")
    print(f"\n Recall: {recall_score(Y_test, Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test, Y_pred)}")
# Out:
# ==========Logistic Regression===========
#
#  Accuaracy: 0.9992563437505668
#
#  Precision: 0.890625
#
#  Recall: 0.6263736263736264
#
#  F1 Score: 0.7354838709677419
#
# ==========Decision Tree Classifier===========
#
#  Accuaracy: 0.9990205503056245
#
#  Precision: 0.6907216494845361
#
#  Recall: 0.7362637362637363
#
#  F1 Score: 0.7127659574468085

# %% [markdown]
# As data is unbalanced we need to undersample/oversample

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal_sample = normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %% [markdown]
# ignore_index ensures continuous is created

# %%
new_data = pd.concat([normal_sample,fraud], ignore_index=True)

# %%
new_data.head()
# Out:
#           V1         V2         V3        V4        V5        V6        V7  \
# 0   0.444929   1.856608  -2.287247  1.532982  0.829166 -1.415018  0.485207
# 1 -12.684076  10.455359 -10.328309 -0.998994 -7.264901 -2.437947 -6.815093
# 2 -10.192051  -7.655064  -2.474987  4.368822  1.472842 -2.950005 -2.876103
# 3   0.912254  -0.211692   0.160843  1.294325 -0.017175  0.384430  0.141553
# 4   1.903679  -0.437197  -0.841554  0.640861 -0.504887 -0.895443 -0.120951
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.325277 -0.714584 -1.238946  ... -0.076531 -0.147406  0.094579 -0.357427
# 1  9.125058  1.021520  2.895122  ...  0.561323  0.658074  1.223303 -0.066820
# 2  0.939755  0.630527  0.212883  ... -1.038129 -0.873630 -6.118295  1.080198
# 3  0.102195 -0.012585 -0.021638  ...  0.005322 -0.039901 -0.225439 -0.271825
# 4 -0.163590  0.918232  0.087921  ... -0.005566 -0.030931  0.189555 -0.017904
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
X = new_data.drop('Class', axis = 1)
Y = new_data['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"\n=========={name}===========")
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(Y_test, Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test, Y_pred)}")
    print(f"\n Recall: {recall_score(Y_test, Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test, Y_pred)}")
# Out:
# ==========Logistic Regression===========
#
#  Accuaracy: 0.9473684210526315
#
#  Precision: 0.9893617021276596
#
#  Recall: 0.9117647058823529
#
#  F1 Score: 0.9489795918367347
#
# ==========Decision Tree Classifier===========
#
#  Accuaracy: 0.9157894736842105
#
#  Precision: 0.9215686274509803
#
#  Recall: 0.9215686274509803
#
#  F1 Score: 0.9215686274509803

# %% [markdown]
# oversampling

# %%
X = data.drop('Class', axis = 1)
Y = data['Class']
Y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res, Y_res = SMOTE().fit_resample(X,Y)

# %%
Y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_res, Y_res, test_size = 0.2, random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"\n=========={name}===========")
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(Y_test, Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test, Y_pred)}")
    print(f"\n Recall: {recall_score(Y_test, Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test, Y_pred)}")
# Out:
# ==========Logistic Regression===========
#
#  Accuaracy: 0.9454740361204985
#
#  Precision: 0.9727909534744602
#
#  Recall: 0.9165136447102885
#
#  F1 Score: 0.9438141241668538
#
# ==========Decision Tree Classifier===========
#
#  Accuaracy: 0.9983465968966896
#
#  Precision: 0.9977663573465052
#
#  Recall: 0.998927331236478
#
#  F1 Score: 0.9983465067684201

# %% [markdown]
# oversampling in decisiontree gives better accuracy

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_res, Y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtc, "CreditCard_fraud.pkl")
# Out:
# ['CreditCard_fraud.pkl']

# %%
loaded_model = joblib.load("CreditCard_fraud.pkl")

# %%
prediction = loaded_model.predict([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
if prediction == 0:
  print("Not Fraud")
else:
  print("Fraud")
# Out:
# [0]
# Not Fraud
